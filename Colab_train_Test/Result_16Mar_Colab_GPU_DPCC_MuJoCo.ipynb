# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# Create a working folder on your Drive
import os
os.makedirs('/content/drive/MyDrive/DPCC', exist_ok=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Set Up wandb

# %%
# !echo $WANDB_MODE

# %%
import wandb
wandb.finish()  # kill the old session

run = wandb.init(
    project="my-project",
    mode="online",
)

print(wandb.run.settings.mode)  # should print 'online'
print(run.url)                  # should give you a wandb.ai link
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/drive/MyDrive/DPCC/dpcc/wandb/run-20260315_221510-rlxfkvud</code>
# Syncing run <strong><a href='https://wandb.ai/llmmail2021-technical-university-of-munich/my-project/runs/rlxfkvud' target="_blank">sunny-bush-3</a></strong> to <a href='https://wandb.ai/llmmail2021-technical-university-of-munich/my-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/llmmail2021-technical-university-of-munich/my-project' target="_blank">https://wandb.ai/llmmail2021-technical-university-of-munich/my-project</a>
#  View run at <a href='https://wandb.ai/llmmail2021-technical-university-of-munich/my-project/runs/rlxfkvud' target="_blank">https://wandb.ai/llmmail2021-technical-university-of-munich/my-project/runs/rlxfkvud</a>
# online
# https://wandb.ai/llmmail2021-technical-university-of-munich/my-project/runs/rlxfkvud

# %%
# ── 1. Reset wandb completely ────────────────────────────────────
import wandb
wandb.finish()          # close any existing run

# ── 2. Force online mode ─────────────────────────────────────────
import os
os.environ['WANDB_MODE'] = 'online'   # set BEFORE login

# ── 3. Now login interactively ───────────────────────────────────
wandb.login(relogin=True)             # relogin=True forces fresh auth

# ── 4. Init ──────────────────────────────────────────────────────
run = wandb.init(
    project="my-project",
    mode="online",        # explicitly set here too
    config={
        "learning_rate": 1e-3,
        "epochs": 10,
    }
)

print(f"Mode: {wandb.run.settings.mode}")  # should print 'online'
print(f"URL:  {run.url}")
# Out:
#  View run <strong style="color:#cdcd00">sunny-bush-3</strong> at: <a href='https://wandb.ai/llmmail2021-technical-university-of-munich/my-project/runs/rlxfkvud' target="_blank">https://wandb.ai/llmmail2021-technical-university-of-munich/my-project/runs/rlxfkvud</a><br> View project at: <a href='https://wandb.ai/llmmail2021-technical-university-of-munich/my-project' target="_blank">https://wandb.ai/llmmail2021-technical-university-of-munich/my-project</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260315_221510-rlxfkvud/logs</code>
# wandb: WARNING Unable to verify login in offline mode.
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/content/drive/MyDrive/DPCC/dpcc/wandb/run-20260315_221544-s7fmfvnc</code>
# Syncing run <strong><a href='https://wandb.ai/llmmail2021-technical-university-of-munich/my-project/runs/s7fmfvnc' target="_blank">autumn-cherry-4</a></strong> to <a href='https://wandb.ai/llmmail2021-technical-university-of-munich/my-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/llmmail2021-technical-university-of-munich/my-project' target="_blank">https://wandb.ai/llmmail2021-technical-university-of-munich/my-project</a>
#  View run at <a href='https://wandb.ai/llmmail2021-technical-university-of-munich/my-project/runs/s7fmfvnc' target="_blank">https://wandb.ai/llmmail2021-technical-university-of-munich/my-project/runs/s7fmfvnc</a>
# Mode: online
# URL:  https://wandb.ai/llmmail2021-technical-university-of-munich/my-project/runs/s7fmfvnc

# %% [markdown]
# # Install Miniconda into Colab (to get Python 3.10)

# %%
# %%bash
# # Install Miniconda (gives us conda + Python 3.10 control)
# if [ ! -f "/content/miniconda.sh" ]; then
#     wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O /content/miniconda.sh
# fi
# bash /content/miniconda.sh -b -p /content/miniconda3 -u
# echo "✓ Miniconda installed"
# /content/miniconda3/bin/conda --version
# Out:
# PREFIX=/content/miniconda3
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /content/miniconda3
# ✓ Miniconda installed
# conda 26.1.1

# %% [markdown]
# # Clone the DPCC Repo (to Drive for persistence)

# %%
# %%bash
# cd /content/drive/MyDrive/DPCC # Corrected directory name
#
# # Only clone if not already there
# if [ ! -d "dpcc" ]; then
#     git clone --recurse-submodules "https://github.com/ghubliming/dpcc.git" # Added quotes to the URL
#     echo "Cloned successfully."
# else
#     echo "Repo already exists, pulling latest..."
#     cd dpcc && git pull
# fi
# Out:
# Repo already exists, pulling latest...
# Already up to date.

# %% [markdown]
# # Create conda env with Python 3.10

# %%
# %%bash
# # Accept Conda Terms of Service for required channels
# /content/miniconda3/bin/conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# /content/miniconda3/bin/conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
#
# # Create env exactly as README says
# /content/miniconda3/bin/conda create -n dpcc python=3.10 -y -q
# echo "✓ conda env 'dpcc' created with Python 3.10"
# /content/miniconda3/envs/dpcc/bin/python --version
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r
# Jupyter detected...
# 2 channel Terms of Service accepted
# Retrieving notices: ...working... done
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /content/miniconda3/envs/dpcc
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ld_impl_linux-64-2.44      |       h9e0c5a2_3         725 KB
#     libnsl-2.0.0               |       h5eee18b_0          31 KB
#     packaging-25.0             |  py310h06a4308_1         164 KB
#     python-3.10.20             |       h741d88c_0        24.1 MB
#     setuptools-80.10.2         |  py310h06a4308_0         1.3 MB
#     sqlite-3.51.2              |       h3e8d24a_0         1.2 MB
#     tzdata-2026a               |       he532380_0         117 KB
#     wheel-0.46.3               |  py310h06a4308_0          54 KB
#     ------------------------------------------------------------
#                                            Total:        27.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2025.12.2-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.44-h9e0c5a2_3
#   libexpat           pkgs/main/linux-64::libexpat-2.7.4-h7354ed3_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc             pkgs/main/linux-64::libgcc-15.2.0-h69a1729_7
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-15.2.0-h166f726_7
#   libgomp            pkgs/main/linux-64::libgomp-15.2.0-h4751f2c_7
#   libnsl             pkgs/main/linux-64::libnsl-2.0.0-h5eee18b_0
#   libstdcxx          pkgs/main/linux-64::libstdcxx-15.2.0-h39759b7_7
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-15.2.0-hc03a8fd_7
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.1-hb25bd0a_0
#   ncurses            pkgs/main/linux-64::ncurses-6.5-h7934f7d_0
#   openssl            pkgs/main/linux-64::openssl-3.5.5-h1b28b03_0
#   packaging          pkgs/main/linux-64::packaging-25.0-py310h06a4308_1
#   pip                pkgs/main/noarch::pip-26.0.1-pyhc872135_0
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   python             pkgs/main/linux-64::python-3.10.20-h741d88c_0
#   readline           pkgs/main/linux-64::readline-8.3-hc2a1206_0
#   setuptools         pkgs/main/linux-64::setuptools-80.10.2-py310h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.51.2-h3e8d24a_0
#   tk                 pkgs/main/linux-64::tk-8.6.15-h54e0aa7_0
#   tzdata             pkgs/main/noarch::tzdata-2026a-he532380_0
#   wheel              pkgs/main/linux-64::wheel-0.46.3-py310h06a4308_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   xz                 pkgs/main/linux-64::xz-5.8.2-h448239c_0
#   zlib               pkgs/main/linux-64::zlib-1.3.1-hb25bd0a_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ✓ conda env 'dpcc' created with Python 3.10
# Python 3.10.20

# %% [markdown]
# # Clone D3IL

# %%
# %%bash
# # 1. Ensure the directory exists before jumping in
# mkdir -p /content/drive/MyDrive/DPCC/dpcc/
#
# D3IL="/content/drive/MyDrive/DPCC/dpcc/d3il"
# # Double check this path exists!
# PIP="/content/miniconda3/envs/dpcc/bin/pip"
#
# if [ ! -f "$PIP" ]; then
#     echo "✗ Critical Error: Pip not found at $PIP. Check your Miniconda installation."
#     exit 1
# fi
#
# # 2. Use a more robust check for the git repo
# if [ ! -d "$D3IL/.git" ]; then
#     echo "d3il missing or incomplete — cleaning and cloning..."
#     rm -rf "$D3IL"
#     git clone https://github.com/ALRhub/d3il.git "$D3IL"
# else
#     echo "✓ d3il repository detected."
# fi
#
# # 3. Use absolute paths for the pip install
# $PIP install "$D3IL/environments/d3il"
# $PIP install "$D3IL/environments/d3il/envs/gym_avoiding_env"
# Out:
# ✓ d3il repository detected.
# Processing ./drive/MyDrive/DPCC/dpcc/d3il/environments/d3il
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: environments.d3il.d3il_sim
#   Building wheel for environments.d3il.d3il_sim (pyproject.toml): started
#   Building wheel for environments.d3il.d3il_sim (pyproject.toml): finished with status 'done'
#   Created wheel for environments.d3il.d3il_sim: filename=environments_d3il_d3il_sim-0.2-py3-none-any.whl size=159418 sha256=f043429711f11bfa51ce8c9a23248495743eb8c01660d1d3909303c44a56923c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2sbkh7fl/wheels/19/38/11/f339016918b730140ec866d0486669dd65174da86a5eae116e
# Successfully built environments.d3il.d3il_sim
# Installing collected packages: environments.d3il.d3il_sim
# Successfully installed environments.d3il.d3il_sim-0.2
# Processing ./drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/envs/gym_avoiding_env
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting gym (from gym_avoiding==0.0.1)
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 24.2 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting numpy>=1.18.0 (from gym->gym_avoiding==0.0.1)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting cloudpickle>=1.2.0 (from gym->gym_avoiding==0.0.1)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting gym_notices>=0.0.4 (from gym->gym_avoiding==0.0.1)
#   Downloading gym_notices-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading gym_notices-0.1.0-py3-none-any.whl (3.3 kB)
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 85.9 MB/s  0:00:00
# Building wheels for collected packages: gym_avoiding, gym
#   Building wheel for gym_avoiding (pyproject.toml): started
#   Building wheel for gym_avoiding (pyproject.toml): finished with status 'done'
#   Created wheel for gym_avoiding: filename=gym_avoiding-0.0.1-py3-none-any.whl size=4965 sha256=694c72a7ade53a29215bd84cbdcc6b17f4e9bf32d7b4ab467c27dbfe1c23b451
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7wx6gtjx/wheels/59/6a/d9/d215f85b576ec58b05db96c674977df715680e2a5a143a2155
#   Building wheel for gym (pyproject.toml): started
#   Building wheel for gym (pyproject.toml): finished with status 'done'
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827728 sha256=bd787af5d118bf9c33ae231ce42a1579fa17fe8cd625ed0d842af6fe130a4d51
#   Stored in directory: /root/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
# Successfully built gym_avoiding gym
# Installing collected packages: gym_notices, numpy, cloudpickle, gym, gym_avoiding
#
# Successfully installed cloudpickle-3.1.2 gym-0.26.2 gym_avoiding-0.0.1 gym_notices-0.1.0 numpy-2.2.6

# %% [markdown]
# # Install PyTorch (CUDA124)

# %%
# %%bash
# /content/miniconda3/envs/dpcc/bin/pip install \
#     torch torchvision \
#     --index-url https://download.pytorch.org/whl/cu124 -q
# echo "✓ PyTorch installed"
# /content/miniconda3/envs/dpcc/bin/python -c \
#     "import torch; print('PyTorch:', torch.__version__); print('CUDA:', torch.cuda.is_available())"
# Out:
# ✓ PyTorch installed
# PyTorch: 2.6.0+cu124
# CUDA: True

# %% [markdown]
# # Install All Requirements

# %%
# %%bash
# PIP="/content/miniconda3/envs/dpcc/bin/pip"
# cd /content/drive/MyDrive/DPCC/dpcc
#
# echo "========================================="
# echo " INSTALLING FROM requirements.txt"
# echo "========================================="
# echo "Using pip: $($PIP --version)"
# echo ""
#
# if [ ! -f requirements.txt ]; then
#   echo "ERROR: requirements.txt not found in $(pwd)"
#   exit 1
# fi
#
# echo "Found requirements.txt -- $(wc -l < requirements.txt) packages listed"
# echo ""
#
# PASS=0
# FAIL=0
# SKIP=0
# FAILED_PKGS=()
#
# while IFS= read -r line || [ -n "$line" ]; do
#   [[ -z "$line" || "$line" == \#* ]] && continue
#
#   PKG="$line"
#   printf "  %-40s" "$PKG"
#
#   RESULT=$($PIP install "$PKG" -q 2>&1)
#   STATUS=$?
#
#   if [ $STATUS -eq 0 ]; then
#     if echo "$RESULT" | grep -q "already satisfied"; then
#       echo "[ already installed ]"
#       ((SKIP++))
#     else
#       echo "[ installed ]"
#       ((PASS++))
#     fi
#   else
#     echo "[ FAILED ]"
#     echo "    └─ $(echo "$RESULT" | tail -3)"
#     FAILED_PKGS+=("$PKG")
#     ((FAIL++))
#   fi
#
# done < requirements.txt
#
# echo ""
# echo "========================================="
# echo " SUMMARY"
# echo "========================================="
# printf "  %-25s %d\n" "Newly installed:"  "$PASS"
# printf "  %-25s %d\n" "Already installed:" "$SKIP"
# printf "  %-25s %d\n" "Failed:"           "$FAIL"
#
# if [ ${#FAILED_PKGS[@]} -gt 0 ]; then
#   echo ""
#   echo "  Failed packages:"
#   for pkg in "${FAILED_PKGS[@]}"; do
#     echo "    - $pkg"
#   done
#   echo ""
#   echo "Setup incomplete. Resolve the above before proceeding."
#   exit 1
# else
#   echo ""
#   echo "All packages installed successfully."
# fi
# Out:
# =========================================
#  INSTALLING FROM requirements.txt
# =========================================
# Using pip: pip 26.0.1 from /content/miniconda3/envs/dpcc/lib/python3.10/site-packages/pip (python 3.10)
#
# Found requirements.txt -- 144 packages listed
#
#   absl-py==2.1.0                          [ installed ]
#   accelerate==0.31.0                      [ installed ]
#   cachetools==5.3.3                       [ installed ]
#   casadi==3.6.5                           [ installed ]
#   certifi==2024.6.2                       [ installed ]
#   charset-normalizer==3.3.2               [ installed ]
#   chex==0.1.86                            [ installed ]
#   clarabel==0.9.0                         [ installed ]
#   click==8.1.7                            [ installed ]
#   cloudpickle==3.0.0                      [ installed ]
#   cmeel==0.53.3                           [ installed ]
#   cmeel-assimp==5.3.1                     [ installed ]
#   cmeel-boost==1.83.0                     [ installed ]
#   cmeel-console-bridge==1.0.2.2           [ installed ]
#   cmeel-octomap==1.9.8.2                  [ installed ]
#   cmeel-qhull==8.0.2.1                    [ installed ]
#   cmeel-tinyxml==2.6.2.3                  [ installed ]
#   cmeel-urdfdom==3.1.1.1                  [ installed ]
#   colorama==0.4.6                         [ installed ]
#   contourpy==1.2.1                        [ installed ]
#   cvxopt==1.3.2                           [ installed ]
#   cvxpy==1.5.2                            [ installed ]
#   cycler==0.12.1                          [ installed ]
#   diffusers==0.31.0                       [ installed ]
#   dill==0.3.8                             [ installed ]
#   docker-pycreds==0.4.0                   [ installed ]
#   ecos==2.0.14                            [ installed ]
#   eigenpy==3.5.1                          [ installed ]
#   einops==0.8.0                           [ installed ]
#   etils==1.9.4                            [ installed ]
#   Farama-Notifications==0.0.4             [ installed ]
#   filelock==3.13.1                        [ installed ]
#   flax==0.8.4                             [ installed ]
#   fonttools==4.53.0                       [ installed ]
#   fsspec==2024.2.0                        [ installed ]
#   gin-config==0.5.0                       [ installed ]
#   gitdb==4.0.11                           [ installed ]
#   GitPython==3.1.43                       [ installed ]
#   glfw==2.7.0                             [ installed ]
#   google-api-core==2.19.0                 [ installed ]
#   google-auth==2.29.0                     [ installed ]
#   google-cloud-core==2.4.1                [ installed ]
#   google-cloud-storage==2.16.0            [ installed ]
#   google-crc32c==1.5.0                    [ installed ]
#   google-resumable-media==2.7.0           [ installed ]
#   googleapis-common-protos==1.63.0        [ installed ]
#   gurobipy==11.0.3                        [ installed ]
#   gym==0.26.2                             [ installed ]
#   gym-notices==0.0.8                      [ installed ]
#   gymnasium==0.29.1                       [ installed ]
#   gymnasium-robotics==1.2.4               [ installed ]
#   h5py==3.11.0                            [ installed ]
#   hpp-fcl==2.4.4                          [ installed ]
#   huggingface-hub==0.23.4                 [ installed ]
#   idna==3.7                               [ installed ]
#   imageio==2.34.1                         [ installed ]
#   importlib_metadata==7.1.0               [ installed ]
#   importlib_resources==6.4.0              [ installed ]
#   jax==0.4.28                             [ installed ]
#   jaxlib==0.4.28                          [ installed ]
#   Jinja2==3.1.3                           [ installed ]
#   joblib==1.4.2                           [ installed ]
#   kiwisolver==1.4.5                       [ installed ]
#   markdown-it-py==3.0.0                   [ installed ]
#   MarkupSafe==2.1.5                       [ installed ]
#   matplotlib==3.9.0                       [ installed ]
#   mc-bin-client==1.0.1                    [ installed ]
#   mdurl==0.1.2                            [ installed ]
#   minari==0.4.3                           [ installed ]
#   ml-dtypes==0.4.0                        [ installed ]
#   mpmath==1.3.0                           [ installed ]
#   msgpack==1.0.8                          [ installed ]
#   mujoco==2.3.7                           [ installed ]
#   nest-asyncio==1.6.0                     [ installed ]
#   networkx==3.2.1                         [ installed ]
#   numpy==1.26.4                           [ installed ]
#   nvidia-cublas-cu12==12.1.3.1            [ installed ]
#   nvidia-cuda-cupti-cu12==12.1.105        [ installed ]
#   nvidia-cuda-nvrtc-cu12==12.1.105        [ installed ]
#   nvidia-cuda-runtime-cu12==12.1.105      [ installed ]
#   nvidia-cudnn-cu12==8.9.2.26             [ installed ]
#   nvidia-cufft-cu12==11.0.2.54            [ installed ]
#   nvidia-curand-cu12==10.3.2.106          [ installed ]
#   nvidia-cusolver-cu12==11.4.5.107        [ installed ]
#   nvidia-cusparse-cu12==12.1.0.106        [ installed ]
#   nvidia-nccl-cu12==2.19.3                [ installed ]
#   nvidia-nvjitlink-cu12==12.1.105         [ installed ]
#   nvidia-nvtx-cu12==12.1.105              [ installed ]
#   opencv-python==4.10.0.84                [ installed ]
#   opt-einsum==3.3.0                       [ installed ]
#   optax==0.2.2                            [ installed ]
#   orbax-checkpoint==0.5.16                [ installed ]
#   osqp==0.6.7.post0                       [ installed ]
#   packaging==24.0                         [ installed ]
#   pettingzoo==1.24.3                      [ installed ]
#   pillow==10.2.0                          [ installed ]
#   pin==2.7.0                              [ installed ]
#   platformdirs==4.2.2                     [ installed ]
#   portion==2.4.2                          [ installed ]
#   proto-plus==1.23.0                      [ installed ]
#   protobuf==4.25.3                        [ installed ]
#   proxsuite==0.6.6                        [ installed ]
#   psutil==5.9.8                           [ installed ]
#   pyarrow==16.1.0                         [ installed ]
#   pyasn1==0.6.0                           [ installed ]
#   pyasn1_modules==0.4.0                   [ installed ]
#   pybullet==3.2.6                         [ installed ]
#   Pygments==2.18.0                        [ installed ]
#   PyOpenGL==3.1.7                         [ installed ]
#   pyparsing==3.1.2                        [ installed ]
#   PyQt5==5.15.10                          [ installed ]
#   PyQt5-Qt5==5.15.2                       [ installed ]
#   PyQt5-sip==12.13.0                      [ installed ]
#   python-dateutil==2.9.0.post0            [ installed ]
#   PyYAML==6.0.1                           [ installed ]
#   qdldl==0.1.7.post4                      [ installed ]
#   qpth==0.0.17                            [ installed ]
#   regex==2024.5.15                        [ installed ]
#   requests==2.32.3                        [ installed ]
#   rich==13.7.1                            [ installed ]
#   rsa==4.9                                [ installed ]
#   safetensors==0.4.3                      [ installed ]
#   scikit-learn==1.5.2                     [ installed ]
#   scipy==1.13.1                           [ installed ]
#   scs==3.2.6                              [ installed ]
#   sentry-sdk==2.12.0                      [ installed ]
#   setproctitle==1.3.3                     [ installed ]
#   shellingham==1.5.4                      [ installed ]
#   six==1.16.0                             [ installed ]
#   smmap==5.0.1                            [ installed ]
#   sortedcontainers==2.4.0                 [ installed ]
#   sympy==1.12                             [ installed ]
#   tensorstore==0.1.62                     [ installed ]
#   threadpoolctl==3.5.0                    [ installed ]
#   tokenizers==0.19.1                      [ installed ]
#   toolz==0.12.1                           [ installed ]
#   tqdm==4.66.4                            [ installed ]
#   transformers==4.41.2                    [ installed ]
#   triton==2.2.0                           [ installed ]
#   typer==0.12.3                           [ installed ]
#   typing_extensions==4.12.1               [ installed ]
#   urllib3==2.2.1                          [ installed ]
#   wandb==0.17.5                           [ installed ]
#   zipp==3.19.1                            [ installed ]
#
# =========================================
#  SUMMARY
# =========================================
#   Newly installed:          144
#   Already installed:        0
#   Failed:                   0
#
# All packages installed successfully.

# %% [markdown]
# # Install D3IL

# %%
# %%bash
# D3IL_ROOT="/content/drive/MyDrive/DPCC/dpcc/d3il"
# PIP="/content/miniconda3/envs/dpcc/bin/pip"
#
# # Install d3il_sim core (correct subdirectory)
# $PIP install -e "$D3IL_ROOT/environments/d3il" -q
#
# # Install gym_avoiding env
# $PIP install -e "$D3IL_ROOT/environments/d3il/envs/gym_avoiding_env" -q
#
# echo "✓ D3IL installed"
# Out:
# ✓ D3IL installed

# %% [markdown]
# # Set PYTHONPATH and MuJoCo renderer

# %%
import sys, os

CONDA_PYTHON = "/content/miniconda3/envs/dpcc/bin/python"
D3IL_ROOT    = "/content/drive/MyDrive/DPCC/dpcc/d3il"
GYM_AV_PATH  = f"{D3IL_ROOT}/environments/d3il/envs/gym_avoiding_env"

# Add paths needed for d3il absolute imports
sys.path.insert(0, D3IL_ROOT)
sys.path.insert(0, GYM_AV_PATH)

os.environ["MUJOCO_GL"]        = "egl"
os.environ["PYOPENGL_PLATFORM"] = "egl"
os.environ["PYTHONPATH"]       = f"{D3IL_ROOT}:{GYM_AV_PATH}:" + os.environ.get("PYTHONPATH","")

print("✓ Paths and env vars set")
# Out:
# ✓ Paths and env vars set

# %% [markdown]
#  # Full verification

# %%
# %%bash
# PYTHON="/content/miniconda3/envs/dpcc/bin/python"
# D3IL_ROOT="/content/drive/MyDrive/DPCC/dpcc/d3il"
# GYM_AV="/content/drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/envs/gym_avoiding_env"
#
# export PYTHONPATH="$D3IL_ROOT:$GYM_AV"
# export MUJOCO_GL="egl"
#
# $PYTHON - << 'EOF'
# import warnings
# warnings.filterwarnings("ignore")
# import sys
#
# print(f"Python:  {sys.version}")
#
# import torch
# print(f"✓ PyTorch {torch.__version__} | CUDA: {torch.cuda.is_available()}")
#
# import mujoco
# print(f"✓ mujoco {mujoco.__version__}")
#
# from environments.d3il import d3il_sim
# print("✓ environments.d3il.d3il_sim")
#
# from environments.d3il.envs.gym_avoiding_env.gym_avoiding.envs.avoiding import ObstacleAvoidanceEnv
# env = ObstacleAvoidanceEnv(render=False)
# env.start()
# obs = env.reset()
# print(f"✓ ObstacleAvoidanceEnv OK | obs shape: {obs.shape}")
#
# print("")
# print("========================================")
# print(" ALL CHECKS PASSED — ready to train!")
# print("========================================")
# EOF
# Out:
# Python:  3.10.20 (main, Mar 11 2026, 17:46:40) [GCC 14.3.0]
# ✓ PyTorch 2.6.0+cu124 | CUDA: True
# ✓ mujoco 2.3.7
# ✓ environments.d3il.d3il_sim
# Final IK error (78 iterations):  7.2858622740627195e-06
# Final IK error (0 iterations):  7.2858622740627195e-06
# ✓ ObstacleAvoidanceEnv OK | obs shape: (2,)
#
# ========================================
#  ALL CHECKS PASSED — ready to train!
# ========================================
# WARNING: mju_openResource: could not open resource '/content/drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/models/mj/robot/panda_tmp_rb0_af4d7364-20b8-11f1-aef0-0242ac1c000c.xml' with default provider at slot 1
# pybullet build time: Nov 28 2023 23:45:17

# %% [markdown]
# # Handle Gurobi

# %%
# After getting license from <https://www.gurobi.com/academia/>
# Upload your gurobi.lic file to Drive, then:
import os
os.environ['GRB_LICENSE_FILE'] = '/content/drive/MyDrive/DPCC/gurobi.lic'

# %% [markdown]
# # Dataset download

# %% [markdown]
# %%bash
# ZIP="/content/drive/MyDrive/DPCC/dpcc/d3il/environments/dataset/data/dataset.zip"
#
# echo "=== Top-level folders in zip ==="
# unzip -l "$ZIP" | awk '{print $4}' | cut -d'/' -f1 | sort -u
#
# echo ""
# echo "=== File count per folder ==="
# unzip -l "$ZIP" | awk '{print $4}' | cut -d'/' -f1 | sort | uniq -c | sort -rn
#
# echo ""
# echo "=== Total uncompressed size ==="
# unzip -l "$ZIP" | tail -1
#
# ```
# === Top-level folders in zip ===
#
# ----
# aligning
# avoiding
# inserting
# Name
# pushing
# sorting
# stacking
#
# === File count per folder ===
# 2638779 sorting
# 1377112 stacking
#  392768 aligning
#    2002 pushing
#     802 inserting
#      99 avoiding
#       3
#       1 Name
#       1 ----
#
# === Total uncompressed size ===
# 17689115292                     4411562 files

# %% [markdown]
# Only Extract the avoiding

# %%
# %%bash
# DATASET_DIR="/content/drive/MyDrive/DPCC/dpcc/d3il/environments/dataset/data"
# AVOIDING_DATA="$DATASET_DIR/avoiding/data"
# ZIP_FILE="$DATASET_DIR/dataset.zip"
#
# echo "========================================="
# echo " D3IL DATASET SETUP"
# echo " Source: ALRhub/d3il README.md"
# echo " Link: https://drive.google.com/file/d/1SQhbhzV85zf_ltnQ8Cbge2lsSWInxVa8"
# echo "========================================="
# echo ""
#
# # ── Step 1: Check if avoiding data already extracted ─────────────
# if [ -d "$AVOIDING_DATA" ] && [ "$(ls -A $AVOIDING_DATA)" ]; then
#     echo "✓ Dataset already extracted at: $AVOIDING_DATA"
#     echo "  Files: $(ls $AVOIDING_DATA | wc -l) found"
#     echo "  Skipping download and extraction."
#     exit 0
# fi
#
# # ── Step 2: Check if zip already downloaded ───────────────────────
# if [ -f "$ZIP_FILE" ]; then
#     echo "✓ Zip already exists: $(du -sh $ZIP_FILE | cut -f1)"
#     echo "  Skipping download."
# else
#     echo "Zip not found. Downloading..."
#     mkdir -p "$DATASET_DIR"
#
#     /content/miniconda3/envs/dpcc/bin/pip install gdown -q
#     echo "✓ gdown ready"
#
#     /content/miniconda3/envs/dpcc/bin/python -m gdown \
#         "https://drive.google.com/uc?id=1SQhbhzV85zf_ltnQ8Cbge2lsSWInxVa8" \
#         -O "$ZIP_FILE"
#
#     if [ ! -f "$ZIP_FILE" ]; then
#         echo "✗ Download failed — zip file not found"
#         exit 1
#     fi
#     echo "✓ Downloaded: $(du -sh $ZIP_FILE | cut -f1)"
# fi
# echo ""
#
# # ── Step 3: Extract ONLY avoiding/ to local Colab disk (fast) ────
# echo "Extracting only avoiding/ to local disk first..."
# LOCAL="/content/avoiding_tmp"
# mkdir -p "$LOCAL"
# unzip -q "$ZIP_FILE" "avoiding/*" -d "$LOCAL"
#
# if [ $? -ne 0 ]; then
#     echo "✗ Extraction failed"
#     rm -rf "$LOCAL"
#     exit 1
# fi
# echo "✓ Extracted locally: $(find $LOCAL -type f | wc -l) files | $(du -sh $LOCAL | cut -f1)"
# echo ""
#
# # ── Step 4: Copy only avoiding/ to Google Drive ───────────────────
# echo "Copying avoiding/ to Google Drive..."
# mkdir -p "$DATASET_DIR/avoiding"
# cp -r "$LOCAL/avoiding/." "$DATASET_DIR/avoiding/"
# echo "✓ Copied to Drive"
#
# # ── Step 5: Cleanup local temp ────────────────────────────────────
# rm -rf "$LOCAL"
# echo "✓ Local temp cleaned up"
# echo ""
#
# # ── Step 6: Final verification ────────────────────────────────────
# echo "========================================="
# echo " VERIFICATION"
# echo "========================================="
# if [ -d "$AVOIDING_DATA" ] && [ "$(ls -A $AVOIDING_DATA)" ]; then
#     echo "✓ avoiding/data found on Drive"
#     echo "  Files: $(ls $AVOIDING_DATA | wc -l)"
#     echo "  Sample: $(ls $AVOIDING_DATA | head -3)"
#     echo ""
#     echo "✓ Dataset ready — you can now run the smoke test."
# else
#     echo "✗ avoiding/data still not found."
#     echo "  Actual structure:"
#     find "$DATASET_DIR" -maxdepth 3 | sort | head -20
#     exit 1
# fi
# Out:
# =========================================
#  D3IL DATASET SETUP
#  Source: ALRhub/d3il README.md
#  Link: https://drive.google.com/file/d/1SQhbhzV85zf_ltnQ8Cbge2lsSWInxVa8
# =========================================
#
# ✓ Zip already exists: 16G
#   Skipping download.
#
# Extracting only avoiding/ to local disk first...
# ✓ Extracted locally: 97 files | 2.6M
#
# Copying avoiding/ to Google Drive...
# ✓ Copied to Drive
# ✓ Local temp cleaned up
#
# =========================================
#  VERIFICATION
# =========================================
# ✓ avoiding/data found on Drive
#   Files: 96
#   Sample: env_000_00.pkl
# env_001_00.pkl
# env_002_00.pkl
#
# ✓ Dataset ready — you can now run the smoke test.

# %% [markdown]
# # Smoke Test Training Cell

# %% [markdown]
# %%bash
# PYTHON="/content/miniconda3/envs/dpcc/bin/python"
# PIP="/content/miniconda3/envs/dpcc/bin/pip"
# DPCC="/content/drive/MyDrive/DPCC/dpcc"
# D3IL_ROOT="$DPCC/d3il"
# GYM_AV="$D3IL_ROOT/environments/d3il/envs/gym_avoiding_env"
#
# export PYTHONPATH="$DPCC:$D3IL_ROOT:$GYM_AV"
# export MUJOCO_GL="egl"
# export WANDB_MODE="offline"
# export MPLBACKEND="agg"
#
# cd $DPCC
#
# # Force reinstall gymnasium and minari to resolve potential import issues
# $PIP install --force-reinstall gymnasium minari -q
#
# $PYTHON - << 'EOF'
# import matplotlib
# matplotlib.use('agg')   # force non-interactive backend before any other import
#
# import torch
# import diffuser.utils as utils
#
# exp = 'avoiding-d3il'
# seeds = [5]
#
# class Parser(utils.Parser):
#     dataset: str = exp
#     config: str = 'config.' + exp
#
# for seed in seeds:
#     args = Parser().parse_args(experiment='diffusion', seed=seed)
#     torch.manual_seed(args.seed)
#
#     # Smoke test overrides
#     args.n_train_steps     = 10
#     args.n_steps_per_epoch = 10
#     args.batch_size        = 2
#
#     print(f"Smoke test: seed={seed} | steps={args.n_train_steps} | batch={args.batch_size}")
#
#     dataset_config = utils.Config(
#         args.loader,
#         savepath=(args.savepath, 'dataset_config.pkl'),
#         env=args.dataset,
#         horizon=args.horizon,
#         normalizer=args.normalizer,
#         preprocess_fns=args.preprocess_fns,
#         use_padding=args.use_padding,
#         max_path_length=args.max_path_length,
#         include_returns=args.include_returns,
#         returns_scale=args.max_path_length,
#         discount=args.discount,
#     )
#     dataset = dataset_config()
#     observation_dim = dataset.observation_dim
#     action_dim      = dataset.action_dim
#     goal_dim        = dataset.goal_dim
#
#     model_config = utils.Config(
#         args.model,
#         savepath=(args.savepath, 'model_config.pkl'),
#         horizon=args.horizon,
#         transition_dim=observation_dim + action_dim,
#         cond_dim=observation_dim,
#         dim_mults=args.dim_mults,
#         returns_condition=args.returns_condition,
#         dim=args.dim,
#         condition_dropout=args.condition_dropout,
#         device=args.device,
#     )
#
#     diffusion_config = utils.Config(
#         args.diffusion,
#         savepath=(args.savepath, 'diffusion_config.pkl'),
#         horizon=args.horizon,
#         observation_dim=observation_dim,
#         action_dim=action_dim,
#         goal_dim=goal_dim,
#         n_timesteps=args.n_diffusion_steps,
#         loss_type=args.loss_type,
#         clip_denoised=args.clip_denoised,
#         predict_epsilon=args.predict_epsilon,
#         action_weight=args.action_weight,
#         loss_discount=args.loss_discount,
#         returns_condition=args.returns_condition,
#         condition_guidance_w=args.condition_guidance_w,
#         device=args.device,
#     )
#
#     trainer_config = utils.Config(
#         utils.Trainer,
#         savepath=(args.savepath, 'trainer_config.pkl'),
#         train_test_split=args.train_test_split,
#         ema_decay=args.ema_decay,
#         n_train_steps=args.n_train_steps,
#         n_steps_per_epoch=args.n_steps_per_epoch,
#         train_batch_size=args.batch_size,
#         train_lr=args.learning_rate,
#         gradient_accumulate_every=args.gradient_accumulate_every,
#         results_folder=args.savepath,
#     )
#
#     model     = model_config()
#     diffusion = diffusion_config(model)
#     trainer   = trainer_config(diffusion, dataset)
#
#     trainer.train()
#     print(f"\n✓ Smoke test PASSED — seed {seed} completed {args.n_train_steps} steps")
#
# print("\n========================================")
# print(" SMOKE TEST COMPLETE — DPCC code works!")
# print("========================================")
# EOF

# %%
# Out:
# Smoke test: seed=5 | steps=10 | batch=2
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.SequenceDataset'>
#     discount: 0.99
#     env: avoiding-d3il
#     horizon: 8
#     include_returns: True
#     max_path_length: 150
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     returns_scale: 150
#     use_padding: True
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5/dataset_config.pkl
#
# [ datasets/buffer ] Fields:
#     observations: (96, 150, 4)
#     actions: (96, 150, 2)
#     rewards: (96, 150, 1)
#     terminals: (96, 150, 1)
#     normed_observations: (96, 150, 4)
#     normed_actions: (96, 150, 2)
#
# [utils/config ] Config: <class 'diffuser.models.unet1d_temporal_cond.UNet1DTemporalCondModel'>
#     cond_dim: 4
#     condition_dropout: 0.25
#     dim: 32
#     dim_mults: (1, 2, 4, 8)
#     horizon: 8
#     returns_condition: False
#     transition_dim: 6
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5/model_config.pkl
#
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 10
#     clip_denoised: False
#     condition_guidance_w: 1.2
#     goal_dim: 0
#     horizon: 8
#     loss_discount: 1.0
#     loss_type: l2
#     n_timesteps: 20
#     observation_dim: 4
#     predict_epsilon: True
#     returns_condition: False
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5/diffusion_config.pkl
#
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     n_steps_per_epoch: 10
#     n_train_steps: 10
#     results_folder: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5
#     train_batch_size: 2
#     train_lr: 0.0001
#     train_test_split: 0.9
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5/trainer_config.pkl
#
# Initial test loss:   0.7515, a0 loss:   0.1121
#
# ✓ Smoke test PASSED — seed 5 completed 10 steps
#
# ========================================
#  SMOKE TEST COMPLETE — DPCC code works!
# ========================================
# WARNING: typer 0.24.1 does not provide the extra 'all'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cmeel-boost 1.83.0 requires numpy~=1.26.0; python_version >= "3.9", but you have numpy 2.2.6 which is incompatible.
# qpth 0.0.17 requires numpy<2,>=1, but you have numpy 2.2.6 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.1.3.1 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.1.105 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.1.105 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.1.105 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 8.9.2.26 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.0.2.54 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.2.106 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.4.5.107 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.1.0.106 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nccl-cu12==2.21.5; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nccl-cu12 2.19.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.1.105 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvtx-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvtx-cu12 12.1.105 which is incompatible.
# torch 2.6.0+cu124 requires sympy==1.13.1; python_version >= "3.9", but you have sympy 1.12 which is incompatible.
# torch 2.6.0+cu124 requires triton==3.2.0; platform_system == "Linux" and platform_machine == "x86_64", but you have triton 2.2.0 which is incompatible.
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# Epoch 0: 100%|██████████| 10/10 [00:05<00:00,  1.81it/s, a0_loss=0.0205, a0_loss_test=0.112, diffusion_loss=1.15, loss=0.577, loss_test=0.751, lr=1e-6, step=9]

# %% [markdown]
#  # Train (using the conda env Python)

# %%
import torch
print(torch.cuda.is_available())       # Must be True
print(torch.cuda.get_device_name(0))   # Should show T4 or similar
# Out:
# True
# Tesla T4

# %% [markdown]
# ### Warning: use Real-time Streaming. Using !python instead of %%bash ensures that as soon as your script prints "Loading model..." or "Epoch 1", you see it immediately.

# %%
import os

# Set paths in the Python environment so they persist
os.environ['DPCC'] = "/content/drive/MyDrive/DPCC/dpcc"
os.environ['PYTHONPATH'] = f"{os.environ['DPCC']}:{os.environ['DPCC']}/d3il:{os.environ['DPCC']}/d3il/environments/d3il/envs/gym_avoiding_env"

# Set GPU and Backend flags
os.environ['MUJOCO_GL'] = "egl"
os.environ['PYOPENGL_PLATFORM'] = "egl"
os.environ['MPLBACKEND'] = "agg"
os.environ['WANDB_MODE'] = "offline"

# Change directory using python so it sticks for the next command
os.chdir(os.environ['DPCC'])

# Run the script using '!' to get real-time streaming output
# !/content/miniconda3/envs/dpcc/bin/python scripts/train.py
# Out:
# [utils/config ] Config: <class 'diffuser.datasets.sequence.SequenceDataset'>
#     discount: 0.99
#     env: avoiding-d3il
#     horizon: 8
#     include_returns: True
#     max_path_length: 150
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     returns_scale: 150
#     use_padding: True
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5/dataset_config.pkl
#
# [ datasets/buffer ] Fields:
#     observations: (96, 150, 4)
#     actions: (96, 150, 2)
#     rewards: (96, 150, 1)
#     terminals: (96, 150, 1)
#     normed_observations: (96, 150, 4)
#     normed_actions: (96, 150, 2)
#
# [utils/config ] Config: <class 'diffuser.models.unet1d_temporal_cond.UNet1DTemporalCondModel'>
#     cond_dim: 4
#     condition_dropout: 0.25
#     dim: 32
#     dim_mults: (1, 2, 4, 8)
#     horizon: 8
#     returns_condition: False
#     transition_dim: 6
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5/model_config.pkl
#
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 10
#     clip_denoised: False
#     condition_guidance_w: 1.2
#     goal_dim: 0
#     horizon: 8
#     loss_discount: 1.0
#     loss_type: l2
#     n_timesteps: 20
#     observation_dim: 4
#     predict_epsilon: True
#     returns_condition: False
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5/diffusion_config.pkl
#
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     n_steps_per_epoch: 1000
#     n_train_steps: 100000.0
#     results_folder: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5
#     train_batch_size: 8
#     train_lr: 0.0001
#     train_test_split: 0.9
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5/trainer_config.pkl
#
# Epoch 0:   0% 0/1000 [00:00<?, ?it/s]Initial test loss:   0.7502, a0 loss:   0.1049
# Epoch 0: 100% 1000/1000 [01:17<00:00, 12.91it/s, a0_loss=0.0241, a0_loss_test=0.105, diffusion_loss=0.794, loss=0.397, loss_test=0.75, lr=0.0001, step=999]
# Epoch 1: 100% 1000/1000 [01:17<00:00, 12.97it/s, a0_loss=0.0108, a0_loss_test=0.0333, diffusion_loss=0.285, loss=0.142, loss_test=0.381, lr=0.0001, step=1999]
# Epoch 2: 100% 1000/1000 [01:22<00:00, 12.11it/s, a0_loss=0.0178, a0_loss_test=0.0242, diffusion_loss=0.265, loss=0.132, loss_test=0.194, lr=9.99e-5, step=2999]
# Epoch 3: 100% 1000/1000 [01:22<00:00, 12.08it/s, a0_loss=0.0375, a0_loss_test=0.0225, diffusion_loss=0.266, loss=0.133, loss_test=0.13, lr=9.98e-5, step=3999]
# Epoch 4: 100% 1000/1000 [01:23<00:00, 12.02it/s, a0_loss=0.0871, a0_loss_test=0.0189, diffusion_loss=0.512, loss=0.256, loss_test=0.103, lr=9.96e-5, step=4999]
# Epoch 5: 100% 1000/1000 [01:20<00:00, 12.47it/s, a0_loss=0.0265, a0_loss_test=0.017, diffusion_loss=0.276, loss=0.138, loss_test=0.0872, lr=9.94e-5, step=5999]
# Epoch 6: 100% 1000/1000 [01:19<00:00, 12.57it/s, a0_loss=0.0107, a0_loss_test=0.0218, diffusion_loss=0.145, loss=0.0723, loss_test=0.0897, lr=9.91e-5, step=6999]
# Epoch 7: 100% 1000/1000 [01:21<00:00, 12.21it/s, a0_loss=0.0138, a0_loss_test=0.017, diffusion_loss=0.143, loss=0.0715, loss_test=0.0762, lr=9.88e-5, step=7999]
# Epoch 8: 100% 1000/1000 [01:22<00:00, 12.08it/s, a0_loss=0.032, a0_loss_test=0.0164, diffusion_loss=0.203, loss=0.102, loss_test=0.071, lr=9.84e-5, step=8999]
# Epoch 9: 100% 1000/1000 [01:20<00:00, 12.38it/s, a0_loss=0.0043, a0_loss_test=0.0189, diffusion_loss=0.0678, loss=0.0339, loss_test=0.0738, lr=9.8e-5, step=9999]
# Epoch 10: 100% 1000/1000 [01:23<00:00, 11.99it/s, a0_loss=0.00755, a0_loss_test=0.0157, diffusion_loss=0.0644, loss=0.0322, loss_test=0.0644, lr=9.75e-5, step=10999]
# Epoch 11: 100% 1000/1000 [01:25<00:00, 11.70it/s, a0_loss=0.0333, a0_loss_test=0.0142, diffusion_loss=0.21, loss=0.105, loss_test=0.0609, lr=9.7e-5, step=11999]
# Epoch 12: 100% 1000/1000 [01:25<00:00, 11.63it/s, a0_loss=0.0261, a0_loss_test=0.0154, diffusion_loss=0.154, loss=0.0768, loss_test=0.0598, lr=9.64e-5, step=12999]
# Epoch 13: 100% 1000/1000 [01:20<00:00, 12.35it/s, a0_loss=0.0196, a0_loss_test=0.0164, diffusion_loss=0.142, loss=0.071, loss_test=0.0629, lr=9.58e-5, step=13999]
# Epoch 14: 100% 1000/1000 [01:21<00:00, 12.28it/s, a0_loss=0.0171, a0_loss_test=0.0144, diffusion_loss=0.17, loss=0.0851, loss_test=0.0552, lr=9.51e-5, step=14999]
# Epoch 15: 100% 1000/1000 [01:17<00:00, 12.98it/s, a0_loss=0.00801, a0_loss_test=0.0116, diffusion_loss=0.0644, loss=0.0322, loss_test=0.0494, lr=9.44e-5, step=15999]
# Epoch 16: 100% 1000/1000 [01:16<00:00, 13.13it/s, a0_loss=0.00227, a0_loss_test=0.0139, diffusion_loss=0.0489, loss=0.0244, loss_test=0.0545, lr=9.37e-5, step=16999]
# Epoch 17: 100% 1000/1000 [01:20<00:00, 12.36it/s, a0_loss=0.0251, a0_loss_test=0.016, diffusion_loss=0.2, loss=0.1, loss_test=0.0589, lr=9.29e-5, step=17999]
# Epoch 18: 100% 1000/1000 [01:20<00:00, 12.36it/s, a0_loss=0.0208, a0_loss_test=0.0138, diffusion_loss=0.135, loss=0.0677, loss_test=0.053, lr=9.21e-5, step=18999]
# Epoch 19: 100% 1000/1000 [01:21<00:00, 12.29it/s, a0_loss=0.0213, a0_loss_test=0.0142, diffusion_loss=0.119, loss=0.0594, loss_test=0.0544, lr=9.12e-5, step=2e+4]
# Epoch 20: 100% 1000/1000 [01:22<00:00, 12.12it/s, a0_loss=0.00568, a0_loss_test=0.0116, diffusion_loss=0.0519, loss=0.026, loss_test=0.046, lr=9.03e-5, step=20999]
# Epoch 21: 100% 1000/1000 [01:22<00:00, 12.06it/s, a0_loss=0.0161, a0_loss_test=0.0125, diffusion_loss=0.102, loss=0.051, loss_test=0.0495, lr=8.93e-5, step=21999]
# Epoch 22: 100% 1000/1000 [01:18<00:00, 12.73it/s, a0_loss=0.0457, a0_loss_test=0.0107, diffusion_loss=0.322, loss=0.161, loss_test=0.0417, lr=8.83e-5, step=22999]
# Epoch 23: 100% 1000/1000 [01:16<00:00, 13.15it/s, a0_loss=0.00877, a0_loss_test=0.0118, diffusion_loss=0.0553, loss=0.0276, loss_test=0.0456, lr=8.73e-5, step=23999]
# Epoch 24: 100% 1000/1000 [01:22<00:00, 12.15it/s, a0_loss=0.0173, a0_loss_test=0.0125, diffusion_loss=0.127, loss=0.0636, loss_test=0.0473, lr=8.62e-5, step=24999]
# Epoch 25: 100% 1000/1000 [01:20<00:00, 12.39it/s, a0_loss=0.00465, a0_loss_test=0.0131, diffusion_loss=0.0458, loss=0.0229, loss_test=0.0489, lr=8.51e-5, step=25999]
# Epoch 26: 100% 1000/1000 [01:16<00:00, 13.16it/s, a0_loss=0.00567, a0_loss_test=0.0113, diffusion_loss=0.0421, loss=0.021, loss_test=0.044, lr=8.39e-5, step=26999]
# Epoch 27: 100% 1000/1000 [01:17<00:00, 12.95it/s, a0_loss=0.00409, a0_loss_test=0.0134, diffusion_loss=0.0387, loss=0.0194, loss_test=0.0491, lr=8.27e-5, step=27999]
# Epoch 28: 100% 1000/1000 [01:21<00:00, 12.33it/s, a0_loss=0.0173, a0_loss_test=0.0138, diffusion_loss=0.126, loss=0.0628, loss_test=0.0484, lr=8.15e-5, step=28999]
# Epoch 29: 100% 1000/1000 [01:22<00:00, 12.17it/s, a0_loss=0.0176, a0_loss_test=0.0125, diffusion_loss=0.1, loss=0.0501, loss_test=0.0493, lr=8.03e-5, step=3e+4]
# Epoch 30: 100% 1000/1000 [01:19<00:00, 12.64it/s, a0_loss=0.0103, a0_loss_test=0.0118, diffusion_loss=0.0946, loss=0.0473, loss_test=0.0438, lr=7.9e-5, step=30999]
# Epoch 31: 100% 1000/1000 [01:21<00:00, 12.33it/s, a0_loss=0.00475, a0_loss_test=0.0104, diffusion_loss=0.0511, loss=0.0255, loss_test=0.0379, lr=7.77e-5, step=31999]
# Epoch 32: 100% 1000/1000 [01:19<00:00, 12.54it/s, a0_loss=0.00194, a0_loss_test=0.0104, diffusion_loss=0.0165, loss=0.00824, loss_test=0.0386, lr=7.64e-5, step=32999]
# Epoch 33: 100% 1000/1000 [01:20<00:00, 12.40it/s, a0_loss=0.00415, a0_loss_test=0.00938, diffusion_loss=0.09, loss=0.045, loss_test=0.0376, lr=7.5e-5, step=33999]
# Epoch 34: 100% 1000/1000 [01:15<00:00, 13.26it/s, a0_loss=0.0106, a0_loss_test=0.00955, diffusion_loss=0.0857, loss=0.0428, loss_test=0.0379, lr=7.36e-5, step=34999]
# Epoch 35: 100% 1000/1000 [01:17<00:00, 12.89it/s, a0_loss=0.00629, a0_loss_test=0.013, diffusion_loss=0.0595, loss=0.0298, loss_test=0.0453, lr=7.22e-5, step=35999]
# Epoch 36: 100% 1000/1000 [01:20<00:00, 12.49it/s, a0_loss=0.0491, a0_loss_test=0.00851, diffusion_loss=0.311, loss=0.155, loss_test=0.0333, lr=7.08e-5, step=36999]
# Epoch 37: 100% 1000/1000 [01:16<00:00, 13.11it/s, a0_loss=0.00382, a0_loss_test=0.00933, diffusion_loss=0.0376, loss=0.0188, loss_test=0.0374, lr=6.93e-5, step=37999]
# Epoch 38: 100% 1000/1000 [01:14<00:00, 13.40it/s, a0_loss=0.00806, a0_loss_test=0.0107, diffusion_loss=0.0696, loss=0.0348, loss_test=0.0388, lr=6.78e-5, step=38999]
# Epoch 39: 100% 1000/1000 [01:14<00:00, 13.35it/s, a0_loss=0.00609, a0_loss_test=0.0118, diffusion_loss=0.0436, loss=0.0218, loss_test=0.0417, lr=6.64e-5, step=4e+4]
# Epoch 40: 100% 1000/1000 [01:16<00:00, 13.12it/s, a0_loss=0.00738, a0_loss_test=0.00933, diffusion_loss=0.0883, loss=0.0442, loss_test=0.0365, lr=6.48e-5, step=40999]
# Epoch 41: 100% 1000/1000 [01:15<00:00, 13.24it/s, a0_loss=0.00474, a0_loss_test=0.0118, diffusion_loss=0.0414, loss=0.0207, loss_test=0.0422, lr=6.33e-5, step=41999]
# Epoch 42: 100% 1000/1000 [01:14<00:00, 13.40it/s, a0_loss=0.0063, a0_loss_test=0.00974, diffusion_loss=0.0528, loss=0.0264, loss_test=0.0381, lr=6.18e-5, step=42999]
# Epoch 43: 100% 1000/1000 [01:14<00:00, 13.49it/s, a0_loss=0.0125, a0_loss_test=0.0118, diffusion_loss=0.078, loss=0.039, loss_test=0.0419, lr=6.02e-5, step=43999]
# Epoch 44: 100% 1000/1000 [01:14<00:00, 13.41it/s, a0_loss=0.00493, a0_loss_test=0.0112, diffusion_loss=0.052, loss=0.026, loss_test=0.0416, lr=5.87e-5, step=44999]
# Epoch 45: 100% 1000/1000 [01:14<00:00, 13.45it/s, a0_loss=0.00345, a0_loss_test=0.0108, diffusion_loss=0.0476, loss=0.0238, loss_test=0.0407, lr=5.71e-5, step=45999]
# Epoch 46: 100% 1000/1000 [01:14<00:00, 13.45it/s, a0_loss=0.0149, a0_loss_test=0.00919, diffusion_loss=0.0947, loss=0.0474, loss_test=0.0358, lr=5.55e-5, step=46999]
# Epoch 47: 100% 1000/1000 [01:16<00:00, 13.11it/s, a0_loss=0.0069, a0_loss_test=0.00901, diffusion_loss=0.0595, loss=0.0298, loss_test=0.036, lr=5.4e-5, step=47999]
# Epoch 48: 100% 1000/1000 [01:19<00:00, 12.55it/s, a0_loss=0.00875, a0_loss_test=0.00973, diffusion_loss=0.0846, loss=0.0423, loss_test=0.035, lr=5.24e-5, step=48999]
# Epoch 49: 100% 1000/1000 [01:20<00:00, 12.38it/s, a0_loss=0.0098, a0_loss_test=0.00899, diffusion_loss=0.0622, loss=0.0311, loss_test=0.0341, lr=5.08e-5, step=5e+4]
# Epoch 50: 100% 1000/1000 [01:19<00:00, 12.55it/s, a0_loss=0.0113, a0_loss_test=0.0101, diffusion_loss=0.103, loss=0.0517, loss_test=0.0374, lr=4.92e-5, step=50999]
# Epoch 51: 100% 1000/1000 [01:19<00:00, 12.54it/s, a0_loss=0.0101, a0_loss_test=0.00981, diffusion_loss=0.0651, loss=0.0325, loss_test=0.0357, lr=4.76e-5, step=51999]
# Epoch 52: 100% 1000/1000 [01:21<00:00, 12.33it/s, a0_loss=0.00417, a0_loss_test=0.00904, diffusion_loss=0.0483, loss=0.0242, loss_test=0.0342, lr=4.6e-5, step=52999]
# Epoch 53: 100% 1000/1000 [01:19<00:00, 12.63it/s, a0_loss=0.0064, a0_loss_test=0.0113, diffusion_loss=0.0541, loss=0.027, loss_test=0.0398, lr=4.45e-5, step=53999]
# Epoch 54: 100% 1000/1000 [01:22<00:00, 12.11it/s, a0_loss=0.00682, a0_loss_test=0.0102, diffusion_loss=0.1, loss=0.0502, loss_test=0.0372, lr=4.29e-5, step=54999]
# Epoch 55: 100% 1000/1000 [01:19<00:00, 12.63it/s, a0_loss=0.00481, a0_loss_test=0.00938, diffusion_loss=0.0558, loss=0.0279, loss_test=0.035, lr=4.13e-5, step=55999]
# Epoch 56: 100% 1000/1000 [01:21<00:00, 12.30it/s, a0_loss=0.00359, a0_loss_test=0.00978, diffusion_loss=0.0317, loss=0.0159, loss_test=0.0349, lr=3.98e-5, step=56999]
# Epoch 57: 100% 1000/1000 [01:21<00:00, 12.22it/s, a0_loss=0.0087, a0_loss_test=0.0091, diffusion_loss=0.0602, loss=0.0301, loss_test=0.0329, lr=3.82e-5, step=57999]
# Epoch 58: 100% 1000/1000 [01:17<00:00, 12.84it/s, a0_loss=0.000515, a0_loss_test=0.00889, diffusion_loss=0.00766, loss=0.00383, loss_test=0.0337, lr=3.67e-5, step=58999]
# Epoch 59: 100% 1000/1000 [01:19<00:00, 12.55it/s, a0_loss=0.0085, a0_loss_test=0.0107, diffusion_loss=0.0576, loss=0.0288, loss_test=0.0375, lr=3.52e-5, step=6e+4]
# Epoch 60: 100% 1000/1000 [01:23<00:00, 11.96it/s, a0_loss=0.00995, a0_loss_test=0.00785, diffusion_loss=0.0736, loss=0.0368, loss_test=0.0319, lr=3.36e-5, step=60999]
# Epoch 61: 100% 1000/1000 [01:20<00:00, 12.42it/s, a0_loss=0.0107, a0_loss_test=0.00984, diffusion_loss=0.0838, loss=0.0419, loss_test=0.035, lr=3.22e-5, step=61999]
# Epoch 62: 100% 1000/1000 [01:21<00:00, 12.27it/s, a0_loss=0.00566, a0_loss_test=0.0101, diffusion_loss=0.0452, loss=0.0226, loss_test=0.0351, lr=3.07e-5, step=62999]
# Epoch 63: 100% 1000/1000 [01:22<00:00, 12.06it/s, a0_loss=0.00178, a0_loss_test=0.00782, diffusion_loss=0.0356, loss=0.0178, loss_test=0.0313, lr=2.92e-5, step=63999]
# Epoch 64: 100% 1000/1000 [01:21<00:00, 12.29it/s, a0_loss=0.0062, a0_loss_test=0.00676, diffusion_loss=0.0802, loss=0.0401, loss_test=0.0272, lr=2.78e-5, step=64999]
# Epoch 65: 100% 1000/1000 [01:21<00:00, 12.25it/s, a0_loss=0.00278, a0_loss_test=0.0086, diffusion_loss=0.0349, loss=0.0175, loss_test=0.032, lr=2.64e-5, step=65999]
# Epoch 66: 100% 1000/1000 [01:19<00:00, 12.54it/s, a0_loss=0.0036, a0_loss_test=0.00704, diffusion_loss=0.0274, loss=0.0137, loss_test=0.0269, lr=2.5e-5, step=66999]
# Epoch 67: 100% 1000/1000 [01:19<00:00, 12.55it/s, a0_loss=0.0246, a0_loss_test=0.00933, diffusion_loss=0.132, loss=0.0661, loss_test=0.0329, lr=2.36e-5, step=67999]
# Epoch 68: 100% 1000/1000 [01:16<00:00, 13.04it/s, a0_loss=0.00558, a0_loss_test=0.00825, diffusion_loss=0.04, loss=0.02, loss_test=0.0308, lr=2.23e-5, step=68999]
# Epoch 69: 100% 1000/1000 [01:15<00:00, 13.24it/s, a0_loss=0.0071, a0_loss_test=0.00777, diffusion_loss=0.063, loss=0.0315, loss_test=0.0303, lr=2.1e-5, step=7e+4]
# Epoch 70: 100% 1000/1000 [01:19<00:00, 12.61it/s, a0_loss=0.000448, a0_loss_test=0.00949, diffusion_loss=0.0137, loss=0.00687, loss_test=0.0337, lr=1.97e-5, step=70999]
# Epoch 71: 100% 1000/1000 [01:19<00:00, 12.62it/s, a0_loss=0.0119, a0_loss_test=0.0088, diffusion_loss=0.0648, loss=0.0324, loss_test=0.0317, lr=1.85e-5, step=71999]
# Epoch 72: 100% 1000/1000 [01:20<00:00, 12.47it/s, a0_loss=0.00711, a0_loss_test=0.00752, diffusion_loss=0.0559, loss=0.0279, loss_test=0.0299, lr=1.73e-5, step=72999]
# Epoch 73: 100% 1000/1000 [01:18<00:00, 12.66it/s, a0_loss=0.00133, a0_loss_test=0.00902, diffusion_loss=0.0418, loss=0.0209, loss_test=0.0334, lr=1.61e-5, step=73999]
# Epoch 74: 100% 1000/1000 [01:18<00:00, 12.80it/s, a0_loss=0.000816, a0_loss_test=0.00855, diffusion_loss=0.0162, loss=0.00808, loss_test=0.0309, lr=1.49e-5, step=74999]
# Epoch 75: 100% 1000/1000 [01:20<00:00, 12.37it/s, a0_loss=0.00185, a0_loss_test=0.00714, diffusion_loss=0.0237, loss=0.0119, loss_test=0.0276, lr=1.38e-5, step=75999]
# Epoch 76: 100% 1000/1000 [01:16<00:00, 13.08it/s, a0_loss=0.0012, a0_loss_test=0.00885, diffusion_loss=0.0281, loss=0.014, loss_test=0.0326, lr=1.27e-5, step=76999]
# Epoch 77: 100% 1000/1000 [01:14<00:00, 13.34it/s, a0_loss=0.0106, a0_loss_test=0.00753, diffusion_loss=0.0624, loss=0.0312, loss_test=0.0279, lr=1.17e-5, step=77999]
# Epoch 78: 100% 1000/1000 [01:16<00:00, 13.13it/s, a0_loss=0.00336, a0_loss_test=0.0085, diffusion_loss=0.0276, loss=0.0138, loss_test=0.0322, lr=1.07e-5, step=78999]
# Epoch 79: 100% 1000/1000 [01:17<00:00, 12.88it/s, a0_loss=0.0018, a0_loss_test=0.00762, diffusion_loss=0.0162, loss=0.00811, loss_test=0.0284, lr=9.74e-6, step=8e+4]
# Epoch 80: 100% 1000/1000 [01:16<00:00, 13.14it/s, a0_loss=0.00247, a0_loss_test=0.00667, diffusion_loss=0.0224, loss=0.0112, loss_test=0.0271, lr=8.82e-6, step=80999]
# Epoch 81: 100% 1000/1000 [01:15<00:00, 13.19it/s, a0_loss=0.00564, a0_loss_test=0.00937, diffusion_loss=0.0843, loss=0.0421, loss_test=0.0328, lr=7.94e-6, step=81999]
# Epoch 82: 100% 1000/1000 [01:16<00:00, 13.15it/s, a0_loss=0.00663, a0_loss_test=0.00744, diffusion_loss=0.0656, loss=0.0328, loss_test=0.0303, lr=7.1e-6, step=82999]
# Epoch 83: 100% 1000/1000 [01:15<00:00, 13.25it/s, a0_loss=0.00117, a0_loss_test=0.00874, diffusion_loss=0.0176, loss=0.00882, loss_test=0.0311, lr=6.31e-6, step=83999]
# Epoch 84: 100% 1000/1000 [01:14<00:00, 13.34it/s, a0_loss=0.00743, a0_loss_test=0.0101, diffusion_loss=0.0411, loss=0.0205, loss_test=0.0337, lr=5.56e-6, step=84999]
# Epoch 85: 100% 1000/1000 [01:22<00:00, 12.18it/s, a0_loss=0.0171, a0_loss_test=0.00649, diffusion_loss=0.087, loss=0.0435, loss_test=0.0248, lr=4.85e-6, step=85999]
# Epoch 86: 100% 1000/1000 [01:21<00:00, 12.25it/s, a0_loss=0.00136, a0_loss_test=0.00758, diffusion_loss=0.0301, loss=0.015, loss_test=0.0278, lr=4.19e-6, step=86999]
# Epoch 87: 100% 1000/1000 [01:27<00:00, 11.41it/s, a0_loss=0.0309, a0_loss_test=0.00674, diffusion_loss=0.177, loss=0.0884, loss_test=0.0262, lr=3.58e-6, step=87999]
# Epoch 88: 100% 1000/1000 [01:28<00:00, 11.25it/s, a0_loss=0.00494, a0_loss_test=0.00724, diffusion_loss=0.0552, loss=0.0276, loss_test=0.0282, lr=3.02e-6, step=88999]
# Epoch 89: 100% 1000/1000 [01:25<00:00, 11.67it/s, a0_loss=0.00158, a0_loss_test=0.00721, diffusion_loss=0.0167, loss=0.00836, loss_test=0.0273, lr=2.5e-6, step=9e+4]
# Epoch 90: 100% 1000/1000 [01:28<00:00, 11.33it/s, a0_loss=0.00417, a0_loss_test=0.00727, diffusion_loss=0.0315, loss=0.0157, loss_test=0.0276, lr=2.03e-6, step=90999]
# Epoch 91: 100% 1000/1000 [01:25<00:00, 11.70it/s, a0_loss=0.00162, a0_loss_test=0.00632, diffusion_loss=0.0266, loss=0.0133, loss_test=0.0266, lr=1.6e-6, step=91999]
# Epoch 92: 100% 1000/1000 [01:27<00:00, 11.41it/s, a0_loss=0.00475, a0_loss_test=0.007, diffusion_loss=0.0506, loss=0.0253, loss_test=0.0257, lr=1.23e-6, step=92999]
# Epoch 93: 100% 1000/1000 [01:27<00:00, 11.48it/s, a0_loss=0.00139, a0_loss_test=0.00719, diffusion_loss=0.0166, loss=0.00828, loss_test=0.0277, lr=9.04e-7, step=93999]
# Epoch 94: 100% 1000/1000 [01:24<00:00, 11.88it/s, a0_loss=0.00541, a0_loss_test=0.00805, diffusion_loss=0.0708, loss=0.0354, loss_test=0.0288, lr=6.28e-7, step=94999]
# Epoch 95: 100% 1000/1000 [01:25<00:00, 11.69it/s, a0_loss=0.00807, a0_loss_test=0.00763, diffusion_loss=0.0552, loss=0.0276, loss_test=0.0292, lr=4.02e-7, step=95999]
# Epoch 96: 100% 1000/1000 [01:27<00:00, 11.41it/s, a0_loss=0.0173, a0_loss_test=0.0071, diffusion_loss=0.139, loss=0.0696, loss_test=0.0279, lr=2.26e-7, step=96999]
# Epoch 97: 100% 1000/1000 [01:25<00:00, 11.72it/s, a0_loss=0.00732, a0_loss_test=0.00729, diffusion_loss=0.0517, loss=0.0259, loss_test=0.0281, lr=1.01e-7, step=97999]
# Epoch 98: 100% 1000/1000 [01:22<00:00, 12.13it/s, a0_loss=0.00635, a0_loss_test=0.00831, diffusion_loss=0.0416, loss=0.0208, loss_test=0.0295, lr=2.52e-8, step=98999]
# Epoch 99: 100% 1000/1000 [01:22<00:00, 12.19it/s, a0_loss=0.00209, a0_loss_test=0.00729, diffusion_loss=0.0394, loss=0.0197, loss_test=0.0267, lr=0, step=1e+5]
# [ utils/setup ] Made savepath: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/6
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.SequenceDataset'>
#     discount: 0.99
#     env: avoiding-d3il
#     horizon: 8
#     include_returns: True
#     max_path_length: 150
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     returns_scale: 150
#     use_padding: True
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/6/dataset_config.pkl
#
# [ datasets/buffer ] Fields:
#     observations: (96, 150, 4)
#     actions: (96, 150, 2)
#     rewards: (96, 150, 1)
#     terminals: (96, 150, 1)
#     normed_observations: (96, 150, 4)
#     normed_actions: (96, 150, 2)
#
# [utils/config ] Config: <class 'diffuser.models.unet1d_temporal_cond.UNet1DTemporalCondModel'>
#     cond_dim: 4
#     condition_dropout: 0.25
#     dim: 32
#     dim_mults: (1, 2, 4, 8)
#     horizon: 8
#     returns_condition: False
#     transition_dim: 6
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/6/model_config.pkl
#
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 10
#     clip_denoised: False
#     condition_guidance_w: 1.2
#     goal_dim: 0
#     horizon: 8
#     loss_discount: 1.0
#     loss_type: l2
#     n_timesteps: 20
#     observation_dim: 4
#     predict_epsilon: True
#     returns_condition: False
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/6/diffusion_config.pkl
#
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     n_steps_per_epoch: 1000
#     n_train_steps: 100000.0
#     results_folder: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/6
#     train_batch_size: 8
#     train_lr: 0.0001
#     train_test_split: 0.9
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/6/trainer_config.pkl
#
# Epoch 0:   0% 0/1000 [00:00<?, ?it/s]Initial test loss:   0.7509, a0 loss:   0.1115
# Epoch 0: 100% 1000/1000 [01:23<00:00, 11.95it/s, a0_loss=0.0414, a0_loss_test=0.112, diffusion_loss=0.853, loss=0.426, loss_test=0.751, lr=0.0001, step=999]
# Epoch 1: 100% 1000/1000 [01:23<00:00, 12.03it/s, a0_loss=0.0371, a0_loss_test=0.0343, diffusion_loss=0.483, loss=0.241, loss_test=0.393, lr=0.0001, step=1999]
# Epoch 2: 100% 1000/1000 [01:22<00:00, 12.14it/s, a0_loss=0.0183, a0_loss_test=0.0256, diffusion_loss=0.195, loss=0.0975, loss_test=0.196, lr=9.99e-5, step=2999]
# Epoch 3: 100% 1000/1000 [01:23<00:00, 11.94it/s, a0_loss=0.0145, a0_loss_test=0.0219, diffusion_loss=0.157, loss=0.0783, loss_test=0.134, lr=9.98e-5, step=3999]
# Epoch 4: 100% 1000/1000 [01:23<00:00, 12.00it/s, a0_loss=0.0109, a0_loss_test=0.0212, diffusion_loss=0.142, loss=0.0712, loss_test=0.105, lr=9.96e-5, step=4999]
# Epoch 5: 100% 1000/1000 [01:23<00:00, 12.03it/s, a0_loss=0.0195, a0_loss_test=0.0219, diffusion_loss=0.199, loss=0.0993, loss_test=0.0995, lr=9.94e-5, step=5999]
# Epoch 6: 100% 1000/1000 [01:21<00:00, 12.28it/s, a0_loss=0.00851, a0_loss_test=0.0197, diffusion_loss=0.0818, loss=0.0409, loss_test=0.0904, lr=9.91e-5, step=6999]
# Epoch 7: 100% 1000/1000 [01:20<00:00, 12.48it/s, a0_loss=0.0373, a0_loss_test=0.0188, diffusion_loss=0.323, loss=0.161, loss_test=0.0845, lr=9.88e-5, step=7999]
# Epoch 8: 100% 1000/1000 [01:21<00:00, 12.33it/s, a0_loss=0.0197, a0_loss_test=0.0189, diffusion_loss=0.133, loss=0.0664, loss_test=0.0811, lr=9.84e-5, step=8999]
# Epoch 9: 100% 1000/1000 [01:19<00:00, 12.60it/s, a0_loss=0.0206, a0_loss_test=0.0155, diffusion_loss=0.228, loss=0.114, loss_test=0.0666, lr=9.8e-5, step=9999]
# Epoch 10: 100% 1000/1000 [01:27<00:00, 11.42it/s, a0_loss=0.00351, a0_loss_test=0.014, diffusion_loss=0.0464, loss=0.0232, loss_test=0.0603, lr=9.75e-5, step=10999]
# Epoch 11: 100% 1000/1000 [01:28<00:00, 11.36it/s, a0_loss=0.0101, a0_loss_test=0.0152, diffusion_loss=0.0833, loss=0.0416, loss_test=0.0617, lr=9.7e-5, step=11999]
# Epoch 12: 100% 1000/1000 [01:25<00:00, 11.69it/s, a0_loss=0.048, a0_loss_test=0.0155, diffusion_loss=0.41, loss=0.205, loss_test=0.0623, lr=9.64e-5, step=12999]
# Epoch 13: 100% 1000/1000 [01:27<00:00, 11.49it/s, a0_loss=0.0183, a0_loss_test=0.0147, diffusion_loss=0.123, loss=0.0613, loss_test=0.0576, lr=9.58e-5, step=13999]
# Epoch 14: 100% 1000/1000 [01:22<00:00, 12.13it/s, a0_loss=0.0175, a0_loss_test=0.0134, diffusion_loss=0.0995, loss=0.0498, loss_test=0.0547, lr=9.51e-5, step=14999]
# Epoch 15: 100% 1000/1000 [01:25<00:00, 11.75it/s, a0_loss=0.0108, a0_loss_test=0.015, diffusion_loss=0.152, loss=0.0758, loss_test=0.0599, lr=9.44e-5, step=15999]
# Epoch 16: 100% 1000/1000 [01:20<00:00, 12.39it/s, a0_loss=0.012, a0_loss_test=0.0105, diffusion_loss=0.104, loss=0.0519, loss_test=0.0456, lr=9.37e-5, step=16999]
# Epoch 17: 100% 1000/1000 [01:25<00:00, 11.69it/s, a0_loss=0.0432, a0_loss_test=0.0133, diffusion_loss=0.222, loss=0.111, loss_test=0.0541, lr=9.29e-5, step=17999]
# Epoch 18: 100% 1000/1000 [01:24<00:00, 11.78it/s, a0_loss=0.007, a0_loss_test=0.0133, diffusion_loss=0.0693, loss=0.0347, loss_test=0.0498, lr=9.21e-5, step=18999]
# Epoch 19: 100% 1000/1000 [01:27<00:00, 11.49it/s, a0_loss=0.00836, a0_loss_test=0.0113, diffusion_loss=0.0664, loss=0.0332, loss_test=0.0478, lr=9.12e-5, step=2e+4]
# Epoch 20: 100% 1000/1000 [01:16<00:00, 13.15it/s, a0_loss=0.051, a0_loss_test=0.0121, diffusion_loss=0.295, loss=0.147, loss_test=0.0469, lr=9.03e-5, step=20999]
# Epoch 21: 100% 1000/1000 [01:15<00:00, 13.23it/s, a0_loss=0.0214, a0_loss_test=0.0132, diffusion_loss=0.161, loss=0.0807, loss_test=0.0512, lr=8.93e-5, step=21999]
# Epoch 22: 100% 1000/1000 [01:25<00:00, 11.73it/s, a0_loss=0.00722, a0_loss_test=0.0141, diffusion_loss=0.059, loss=0.0295, loss_test=0.0516, lr=8.83e-5, step=22999]
# Epoch 23: 100% 1000/1000 [01:23<00:00, 11.93it/s, a0_loss=0.00216, a0_loss_test=0.013, diffusion_loss=0.03, loss=0.015, loss_test=0.0468, lr=8.73e-5, step=23999]
# Epoch 24: 100% 1000/1000 [01:23<00:00, 11.96it/s, a0_loss=0.0043, a0_loss_test=0.0134, diffusion_loss=0.0429, loss=0.0214, loss_test=0.0491, lr=8.62e-5, step=24999]
# Epoch 25: 100% 1000/1000 [01:22<00:00, 12.07it/s, a0_loss=0.0453, a0_loss_test=0.0109, diffusion_loss=0.294, loss=0.147, loss_test=0.0435, lr=8.51e-5, step=25999]
# Epoch 26: 100% 1000/1000 [01:21<00:00, 12.31it/s, a0_loss=0.0126, a0_loss_test=0.0121, diffusion_loss=0.159, loss=0.0795, loss_test=0.0464, lr=8.39e-5, step=26999]
# Epoch 27: 100% 1000/1000 [01:27<00:00, 11.46it/s, a0_loss=0.0181, a0_loss_test=0.00905, diffusion_loss=0.106, loss=0.0529, loss_test=0.0383, lr=8.27e-5, step=27999]
# Epoch 28: 100% 1000/1000 [01:27<00:00, 11.41it/s, a0_loss=0.00373, a0_loss_test=0.0112, diffusion_loss=0.0311, loss=0.0156, loss_test=0.0432, lr=8.15e-5, step=28999]
# Epoch 29: 100% 1000/1000 [01:26<00:00, 11.53it/s, a0_loss=0.00516, a0_loss_test=0.0114, diffusion_loss=0.046, loss=0.023, loss_test=0.0451, lr=8.03e-5, step=3e+4]
# Epoch 30: 100% 1000/1000 [01:26<00:00, 11.59it/s, a0_loss=0.00572, a0_loss_test=0.0107, diffusion_loss=0.0409, loss=0.0204, loss_test=0.0418, lr=7.9e-5, step=30999]
# Epoch 31: 100% 1000/1000 [01:22<00:00, 12.06it/s, a0_loss=0.0201, a0_loss_test=0.011, diffusion_loss=0.106, loss=0.0532, loss_test=0.0441, lr=7.77e-5, step=31999]
# Epoch 32: 100% 1000/1000 [01:25<00:00, 11.64it/s, a0_loss=0.00653, a0_loss_test=0.0126, diffusion_loss=0.0644, loss=0.0322, loss_test=0.0467, lr=7.64e-5, step=32999]
# Epoch 33: 100% 1000/1000 [01:28<00:00, 11.30it/s, a0_loss=0.00507, a0_loss_test=0.0102, diffusion_loss=0.0708, loss=0.0354, loss_test=0.0409, lr=7.5e-5, step=33999]
# Epoch 34: 100% 1000/1000 [01:25<00:00, 11.66it/s, a0_loss=0.014, a0_loss_test=0.0103, diffusion_loss=0.0701, loss=0.0351, loss_test=0.0409, lr=7.36e-5, step=34999]
# Epoch 35: 100% 1000/1000 [01:28<00:00, 11.35it/s, a0_loss=0.00813, a0_loss_test=0.0106, diffusion_loss=0.0507, loss=0.0254, loss_test=0.0416, lr=7.22e-5, step=35999]
# Epoch 36: 100% 1000/1000 [01:28<00:00, 11.24it/s, a0_loss=0.00323, a0_loss_test=0.0101, diffusion_loss=0.0399, loss=0.02, loss_test=0.0388, lr=7.08e-5, step=36999]
# Epoch 37: 100% 1000/1000 [01:28<00:00, 11.31it/s, a0_loss=0.0177, a0_loss_test=0.0134, diffusion_loss=0.112, loss=0.0559, loss_test=0.0461, lr=6.93e-5, step=37999]
# Epoch 38: 100% 1000/1000 [01:27<00:00, 11.45it/s, a0_loss=0.00158, a0_loss_test=0.0099, diffusion_loss=0.0407, loss=0.0203, loss_test=0.0386, lr=6.78e-5, step=38999]
# Epoch 39: 100% 1000/1000 [01:25<00:00, 11.73it/s, a0_loss=0.011, a0_loss_test=0.00991, diffusion_loss=0.0916, loss=0.0458, loss_test=0.0384, lr=6.64e-5, step=4e+4]
# Epoch 40: 100% 1000/1000 [01:26<00:00, 11.59it/s, a0_loss=0.00557, a0_loss_test=0.0105, diffusion_loss=0.0335, loss=0.0167, loss_test=0.0387, lr=6.48e-5, step=40999]
# Epoch 41: 100% 1000/1000 [01:29<00:00, 11.18it/s, a0_loss=0.00119, a0_loss_test=0.00964, diffusion_loss=0.0225, loss=0.0112, loss_test=0.0383, lr=6.33e-5, step=41999]
# Epoch 42: 100% 1000/1000 [01:29<00:00, 11.13it/s, a0_loss=0.0219, a0_loss_test=0.00928, diffusion_loss=0.155, loss=0.0773, loss_test=0.0374, lr=6.18e-5, step=42999]
# Epoch 43: 100% 1000/1000 [01:24<00:00, 11.80it/s, a0_loss=0.00548, a0_loss_test=0.00991, diffusion_loss=0.0634, loss=0.0317, loss_test=0.037, lr=6.02e-5, step=43999]
# Epoch 44: 100% 1000/1000 [01:25<00:00, 11.66it/s, a0_loss=0.0049, a0_loss_test=0.0127, diffusion_loss=0.0457, loss=0.0228, loss_test=0.0442, lr=5.87e-5, step=44999]
# Epoch 45: 100% 1000/1000 [01:24<00:00, 11.79it/s, a0_loss=0.0069, a0_loss_test=0.0103, diffusion_loss=0.0461, loss=0.0231, loss_test=0.039, lr=5.71e-5, step=45999]
# Epoch 46: 100% 1000/1000 [01:30<00:00, 11.01it/s, a0_loss=0.00208, a0_loss_test=0.0115, diffusion_loss=0.0568, loss=0.0284, loss_test=0.043, lr=5.55e-5, step=46999]
# Epoch 47: 100% 1000/1000 [01:30<00:00, 11.11it/s, a0_loss=0.0244, a0_loss_test=0.00861, diffusion_loss=0.152, loss=0.0762, loss_test=0.034, lr=5.4e-5, step=47999]
# Epoch 48: 100% 1000/1000 [01:29<00:00, 11.21it/s, a0_loss=0.00908, a0_loss_test=0.0102, diffusion_loss=0.104, loss=0.0519, loss_test=0.0377, lr=5.24e-5, step=48999]
# Epoch 49: 100% 1000/1000 [01:27<00:00, 11.39it/s, a0_loss=0.0127, a0_loss_test=0.00862, diffusion_loss=0.0733, loss=0.0367, loss_test=0.0344, lr=5.08e-5, step=5e+4]
# Epoch 50: 100% 1000/1000 [01:28<00:00, 11.31it/s, a0_loss=0.00894, a0_loss_test=0.0102, diffusion_loss=0.0571, loss=0.0286, loss_test=0.0376, lr=4.92e-5, step=50999]
# Epoch 51: 100% 1000/1000 [01:29<00:00, 11.14it/s, a0_loss=0.00491, a0_loss_test=0.00891, diffusion_loss=0.0487, loss=0.0243, loss_test=0.0353, lr=4.76e-5, step=51999]
# Epoch 52: 100% 1000/1000 [01:29<00:00, 11.19it/s, a0_loss=0.00145, a0_loss_test=0.00949, diffusion_loss=0.0172, loss=0.00862, loss_test=0.0357, lr=4.6e-5, step=52999]
# Epoch 53: 100% 1000/1000 [01:29<00:00, 11.18it/s, a0_loss=0.00481, a0_loss_test=0.00917, diffusion_loss=0.0468, loss=0.0234, loss_test=0.0351, lr=4.45e-5, step=53999]
# Epoch 54: 100% 1000/1000 [01:27<00:00, 11.38it/s, a0_loss=0.00621, a0_loss_test=0.0088, diffusion_loss=0.0655, loss=0.0327, loss_test=0.0336, lr=4.29e-5, step=54999]
# Epoch 55: 100% 1000/1000 [01:25<00:00, 11.70it/s, a0_loss=0.0157, a0_loss_test=0.00855, diffusion_loss=0.0958, loss=0.0479, loss_test=0.0319, lr=4.13e-5, step=55999]
# Epoch 56: 100% 1000/1000 [01:27<00:00, 11.48it/s, a0_loss=0.00875, a0_loss_test=0.00927, diffusion_loss=0.0631, loss=0.0316, loss_test=0.0343, lr=3.98e-5, step=56999]
# Epoch 57: 100% 1000/1000 [01:26<00:00, 11.57it/s, a0_loss=0.00891, a0_loss_test=0.00877, diffusion_loss=0.0706, loss=0.0353, loss_test=0.0335, lr=3.82e-5, step=57999]
# Epoch 58: 100% 1000/1000 [01:27<00:00, 11.45it/s, a0_loss=0.00246, a0_loss_test=0.00877, diffusion_loss=0.0591, loss=0.0295, loss_test=0.0328, lr=3.67e-5, step=58999]
# Epoch 59: 100% 1000/1000 [01:26<00:00, 11.62it/s, a0_loss=0.00228, a0_loss_test=0.00947, diffusion_loss=0.043, loss=0.0215, loss_test=0.0338, lr=3.52e-5, step=6e+4]
# Epoch 60: 100% 1000/1000 [01:29<00:00, 11.14it/s, a0_loss=0.00574, a0_loss_test=0.00714, diffusion_loss=0.0406, loss=0.0203, loss_test=0.0296, lr=3.36e-5, step=60999]
# Epoch 61: 100% 1000/1000 [01:27<00:00, 11.42it/s, a0_loss=0.00734, a0_loss_test=0.00836, diffusion_loss=0.0544, loss=0.0272, loss_test=0.0329, lr=3.22e-5, step=61999]
# Epoch 62: 100% 1000/1000 [01:26<00:00, 11.56it/s, a0_loss=0.0047, a0_loss_test=0.00801, diffusion_loss=0.0372, loss=0.0186, loss_test=0.0306, lr=3.07e-5, step=62999]
# Epoch 63: 100% 1000/1000 [01:25<00:00, 11.68it/s, a0_loss=0.0026, a0_loss_test=0.00839, diffusion_loss=0.017, loss=0.00848, loss_test=0.0324, lr=2.92e-5, step=63999]
# Epoch 64: 100% 1000/1000 [01:24<00:00, 11.86it/s, a0_loss=0.0103, a0_loss_test=0.00796, diffusion_loss=0.0835, loss=0.0417, loss_test=0.0307, lr=2.78e-5, step=64999]
# Epoch 65: 100% 1000/1000 [01:22<00:00, 12.18it/s, a0_loss=0.00575, a0_loss_test=0.0092, diffusion_loss=0.0409, loss=0.0204, loss_test=0.035, lr=2.64e-5, step=65999]
# Epoch 66: 100% 1000/1000 [01:24<00:00, 11.87it/s, a0_loss=0.00215, a0_loss_test=0.00903, diffusion_loss=0.0274, loss=0.0137, loss_test=0.0322, lr=2.5e-5, step=66999]
# Epoch 67: 100% 1000/1000 [01:25<00:00, 11.70it/s, a0_loss=0.00318, a0_loss_test=0.00933, diffusion_loss=0.0501, loss=0.0251, loss_test=0.0346, lr=2.36e-5, step=67999]
# Epoch 68: 100% 1000/1000 [01:25<00:00, 11.76it/s, a0_loss=0.00599, a0_loss_test=0.00923, diffusion_loss=0.041, loss=0.0205, loss_test=0.0336, lr=2.23e-5, step=68999]
# Epoch 69: 100% 1000/1000 [01:21<00:00, 12.23it/s, a0_loss=0.00387, a0_loss_test=0.0088, diffusion_loss=0.0352, loss=0.0176, loss_test=0.0325, lr=2.1e-5, step=7e+4]
# Epoch 70: 100% 1000/1000 [01:27<00:00, 11.43it/s, a0_loss=0.00358, a0_loss_test=0.0083, diffusion_loss=0.091, loss=0.0455, loss_test=0.0313, lr=1.97e-5, step=70999]
# Epoch 71: 100% 1000/1000 [01:26<00:00, 11.59it/s, a0_loss=0.0032, a0_loss_test=0.00909, diffusion_loss=0.0346, loss=0.0173, loss_test=0.0318, lr=1.85e-5, step=71999]
# Epoch 72: 100% 1000/1000 [01:27<00:00, 11.41it/s, a0_loss=0.0111, a0_loss_test=0.00737, diffusion_loss=0.0793, loss=0.0397, loss_test=0.029, lr=1.73e-5, step=72999]
# Epoch 73: 100% 1000/1000 [01:28<00:00, 11.30it/s, a0_loss=0.0132, a0_loss_test=0.00671, diffusion_loss=0.102, loss=0.051, loss_test=0.0271, lr=1.61e-5, step=73999]
# Epoch 74: 100% 1000/1000 [01:26<00:00, 11.51it/s, a0_loss=0.00189, a0_loss_test=0.00818, diffusion_loss=0.0116, loss=0.00582, loss_test=0.03, lr=1.49e-5, step=74999]
# Epoch 75: 100% 1000/1000 [01:22<00:00, 12.09it/s, a0_loss=0.00536, a0_loss_test=0.00738, diffusion_loss=0.0481, loss=0.024, loss_test=0.0283, lr=1.38e-5, step=75999]
# Epoch 76: 100% 1000/1000 [01:25<00:00, 11.73it/s, a0_loss=0.00893, a0_loss_test=0.00753, diffusion_loss=0.0585, loss=0.0292, loss_test=0.0287, lr=1.27e-5, step=76999]
# Epoch 77: 100% 1000/1000 [01:25<00:00, 11.68it/s, a0_loss=0.0206, a0_loss_test=0.00707, diffusion_loss=0.133, loss=0.0665, loss_test=0.0298, lr=1.17e-5, step=77999]
# Epoch 78: 100% 1000/1000 [01:27<00:00, 11.44it/s, a0_loss=0.018, a0_loss_test=0.00629, diffusion_loss=0.0961, loss=0.0481, loss_test=0.026, lr=1.07e-5, step=78999]
# Epoch 79: 100% 1000/1000 [01:27<00:00, 11.41it/s, a0_loss=0.00224, a0_loss_test=0.00901, diffusion_loss=0.018, loss=0.00898, loss_test=0.0326, lr=9.74e-6, step=8e+4]
# Epoch 80: 100% 1000/1000 [01:27<00:00, 11.44it/s, a0_loss=0.00389, a0_loss_test=0.00722, diffusion_loss=0.0511, loss=0.0255, loss_test=0.0278, lr=8.82e-6, step=80999]
# Epoch 81: 100% 1000/1000 [01:27<00:00, 11.43it/s, a0_loss=0.00927, a0_loss_test=0.00709, diffusion_loss=0.065, loss=0.0325, loss_test=0.0281, lr=7.94e-6, step=81999]
# Epoch 82: 100% 1000/1000 [01:25<00:00, 11.66it/s, a0_loss=0.00343, a0_loss_test=0.00649, diffusion_loss=0.0186, loss=0.0093, loss_test=0.0265, lr=7.1e-6, step=82999]
# Epoch 83: 100% 1000/1000 [01:27<00:00, 11.46it/s, a0_loss=0.00458, a0_loss_test=0.00913, diffusion_loss=0.0622, loss=0.0311, loss_test=0.0326, lr=6.31e-6, step=83999]
# Epoch 84: 100% 1000/1000 [01:29<00:00, 11.22it/s, a0_loss=0.0147, a0_loss_test=0.00693, diffusion_loss=0.131, loss=0.0657, loss_test=0.0265, lr=5.56e-6, step=84999]
# Epoch 85: 100% 1000/1000 [01:30<00:00, 11.05it/s, a0_loss=0.0041, a0_loss_test=0.00628, diffusion_loss=0.0542, loss=0.0271, loss_test=0.0258, lr=4.85e-6, step=85999]
# Epoch 86: 100% 1000/1000 [01:21<00:00, 12.28it/s, a0_loss=0.00319, a0_loss_test=0.007, diffusion_loss=0.0239, loss=0.012, loss_test=0.0269, lr=4.19e-6, step=86999]
# Epoch 87: 100% 1000/1000 [01:21<00:00, 12.26it/s, a0_loss=0.00355, a0_loss_test=0.00761, diffusion_loss=0.0291, loss=0.0146, loss_test=0.0292, lr=3.58e-6, step=87999]
# Epoch 88: 100% 1000/1000 [01:23<00:00, 11.99it/s, a0_loss=0.013, a0_loss_test=0.00705, diffusion_loss=0.0694, loss=0.0347, loss_test=0.0273, lr=3.02e-6, step=88999]
# Epoch 89: 100% 1000/1000 [01:21<00:00, 12.23it/s, a0_loss=0.00176, a0_loss_test=0.00866, diffusion_loss=0.0218, loss=0.0109, loss_test=0.0319, lr=2.5e-6, step=9e+4]
# Epoch 90: 100% 1000/1000 [01:23<00:00, 11.91it/s, a0_loss=0.00728, a0_loss_test=0.00727, diffusion_loss=0.119, loss=0.0593, loss_test=0.0278, lr=2.03e-6, step=90999]
# Epoch 91: 100% 1000/1000 [01:27<00:00, 11.48it/s, a0_loss=0.0072, a0_loss_test=0.00567, diffusion_loss=0.0546, loss=0.0273, loss_test=0.0242, lr=1.6e-6, step=91999]
# Epoch 92: 100% 1000/1000 [01:25<00:00, 11.75it/s, a0_loss=0.00109, a0_loss_test=0.00771, diffusion_loss=0.0109, loss=0.00546, loss_test=0.027, lr=1.23e-6, step=92999]
# Epoch 93:  52% 516/1000 [00:46<00:37, 12.94it/s, a0_loss=0.00447, a0_loss_test=0.00762, diffusion_loss=0.0466, loss=0.0233, loss_test=0.0292, lr=1.05e-6, step=93515]

# %% [markdown]
# # Set Up Virtual Display for MuJoCo Rendering

# %%
import os
import subprocess

# 1. Start Xvfb (Virtual Framebuffer)
# We check if it's already running to avoid multiple instances
try:
    subprocess.Popen(['Xvfb', ':1', '-screen', '0', '1400x900x24'])
except FileNotFoundError:
    # !apt-get install -y xvfb
    subprocess.Popen(['Xvfb', ':1', '-screen', '0', '1400x900x24'])

# 2. Set Environment Variables
os.environ['DISPLAY'] = ':1'
os.environ['MUJOCO_GL'] = 'egl'
os.environ['PYOPENGL_PLATFORM'] = 'egl'

# 3. Verify MuJoCo using your CONDA python
# This ensures we use the version installed in your 'dpcc' environment
# !/content/miniconda3/envs/dpcc/bin/python -c "import mujoco; print('MuJoCo version:', mujoco.__version__)"
# Out:
# MuJoCo version: 2.3.7

# %% [markdown]
# # Evaluate

# %%
import os

# 1. Path Setup (Colab specific)
DPCC = "/content/drive/MyDrive/DPCC/dpcc"
D3IL_ROOT = f"{DPCC}/d3il"
GYM_AV = f"{D3IL_ROOT}/environments/d3il/envs/gym_avoiding_env"
PYTHON_BIN = "/content/miniconda3/envs/dpcc/bin/python"

# 2. Environment Setup (Matching your CPU logic but for GPU)
os.environ['MUJOCO_GL'] = 'egl'         # Colab GPU uses EGL
os.environ['PYOPENGL_PLATFORM'] = 'egl'
os.environ['WANDB_MODE'] = 'offline'
os.environ['PYTHONPATH'] = f"{DPCC}:{D3IL_ROOT}:{GYM_AV}"

# 3. Matplotlib Fix (The "Unset/Reset" logic from your CPU)
os.environ.pop('MPLBACKEND', None)
os.environ['MPLBACKEND'] = 'agg'

# 4. Execute with Streaming
os.chdir(DPCC)

print("--- Running Evaluation ---")
# !{PYTHON_BIN} scripts/eval.py

print("\n--- Loading Results ---")
# !{PYTHON_BIN} scripts/load_results.py
# Out:
# --- Running Evaluation ---
#
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/content/drive/MyDrive/DPCC/dpcc/scripts/eval.py", line 12, in <module>
#     from d3il.environments.d3il.envs.gym_avoiding_env.gym_avoiding.envs.avoiding import ObstacleAvoidanceEnv
#   File "/content/drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/envs/gym_avoiding_env/gym_avoiding/envs/__init__.py", line 1, in <module>
#     from .avoiding import ObstacleAvoidanceEnv
#   File "/content/drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/envs/gym_avoiding_env/gym_avoiding/envs/avoiding.py", line 3, in <module>
#     from environments.d3il.d3il_sim.sims.mj_beta.mj_utils.mj_helper import has_collision
#   File "/content/drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/d3il_sim/sims/__init__.py", line 1, in <module>
#     from .mj_beta import *
#   File "/content/drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/d3il_sim/sims/mj_beta/__init__.py", line 6, in <module>
#     from .MjFactory import *
#   File "/content/drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/d3il_sim/sims/mj_beta/MjFactory.py", line 3, in <module>
#     import environments.d3il.d3il_sim.sims.SimFactory as Sims
#   File "/content/drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/d3il_sim/sims/SimFactory.py", line 4, in <module>
#     from environments.d3il.d3il_sim.core import Camera, RobotBase, Scene
#   File "/content/drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/d3il_sim/core/__init__.py", line 2, in <module>
#     from .Model import *
#   File "/content/drive/MyDrive/DPCC/dpcc/d3il/environments/d3il/d3il_sim/core/Model.py", line 2, in <module>
#     import pinocchio
#   File "/content/miniconda3/envs/dpcc/lib/python3.10/site-packages/cmeel.prefix/lib/python3.10/site-packages/pinocchio/__init__.py", line 18, in <module>
#     from .pinocchio_pywrap import *
# Traceback (most recent call last):
#   File "/content/miniconda3/envs/dpcc/lib/python3.10/site-packages/numpy/core/_multiarray_umath.py", line 44, in __getattr__
#     raise ImportError(msg)
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
#
#
# --- Loading Results ---
# [ utils/setup ] Made savepath: logs/avoiding-d3il/plans/H8_K20_Dmodels.GaussianDiffusion/0
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/DPCC/dpcc/scripts/load_results.py", line 37, in <module>
#     data = np.load(f'{args.savepath}/results/halfspace_{halfspace_variant}/{variant}.npz', allow_pickle=True)
#   File "/content/miniconda3/envs/dpcc/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py", line 451, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
# FileNotFoundError: [Errno 2] No such file or directory: 'logs/avoiding-d3il/plans/H8_K20_Dmodels.GaussianDiffusion/0/results/halfspace_top-right-hard/dpcc-r.npz'

# %% [markdown]
# #  Visualize

# %%
import os

# Define paths
dpcc_dir = "/content/drive/MyDrive/DPCC/dpcc"
d3il_dir = f"{dpcc_dir}/d3il"
gym_dir = f"{d3il_dir}/environments/d3il/envs/gym_avoiding_env"

# Setup environment variables
os.environ['MUJOCO_GL'] = "egl"
os.environ['PYOPENGL_PLATFORM'] = "egl"
os.environ['DISPLAY'] = ":1"
os.environ['MPLBACKEND'] = "agg"
os.environ['PYTHONPATH'] = f"{dpcc_dir}:{d3il_dir}:{gym_dir}"

# Move to the working directory
os.chdir(dpcc_dir)

# Stream the visualization output
# !/content/miniconda3/envs/dpcc/bin/python scripts/visualize_data_constraints.py
# Out:
# Halfspace variant: top-right-hard
# Number of feasible trajectories: 1/96, 1.04%
# Halfspace variant: top-left-hard
# Number of feasible trajectories: 0/96, 0.00%
# Halfspace variant: both-hard
# Number of feasible trajectories: 2/96, 2.08%
# /content/drive/MyDrive/DPCC/dpcc/scripts/visualize_data_constraints.py:165: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
